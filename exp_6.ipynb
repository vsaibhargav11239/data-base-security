# %% [markdown]
# <a href="https://colab.research.google.com/github/vsaibhargav11239/data-base-security/blob/main/exp_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycryptodome
# Out:
# Collecting pycryptodome
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 21.2 MB/s eta 0:00:00
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.23.0

# %%
from Cryptodome.Cipher import DES
from Cryptodome.Util.Padding import pad, unpad
from Cryptodome.Random import get_random_bytes
import binascii

class DESExample:
    def __init__(self):
        self.raw_key = self.generate_symmetric_key()
        self.input_message = input("Enter message to encrypt: ")

        # Encrypt the input message
        encrypted_data = self.encrypt(self.raw_key, self.input_message.encode())
        print("Encrypted message (hex):", binascii.hexlify(encrypted_data).decode())

        # Decrypt the message
        decrypted_message = self.decrypt(self.raw_key, encrypted_data)
        print("Decrypted message:", decrypted_message.decode())


    def generate_symmetric_key(self):
        # Generate a random key for DES (must be 8 bytes)
        key = get_random_bytes(8)
        print("DES Symmetric key (hex):", binascii.hexlify(key).decode())
        return key

    def encrypt(self, key, clear):
        # Create a DES cipher object
        cipher = DES.new(key, DES.MODE_CBC)
        # Pad the plaintext
        padded_clear = pad(clear, DES.block_size)
        # Encrypt the padded plaintext
        iv = cipher.iv
        encrypted = iv + cipher.encrypt(padded_clear)  # Prepend IV to ciphertext
        return encrypted
    def decrypt(self, key, encrypted):
        # Extract the IV from the beginning of the encrypted data
        iv = encrypted[:DES.block_size]
        ciphertext = encrypted[DES.block_size:]
        # Create a DES cipher object with the same IV
        cipher = DES.new(key, DES.MODE_CBC, iv)
        # Decrypt the ciphertext
        decrypted_padded_clear = cipher.decrypt(ciphertext)
        # Unpad the decrypted plaintext
        return unpad(decrypted_padded_clear, DES.block_size)

if __name__ == "__main__":
    DESExample()
# Out:
# DES Symmetric key (hex): 4288760e4042212b
# Enter message to encrypt: sai
# Encrypted message (hex): 149697b0285108e94d4b0cdc98ee2045
# Decrypted message: sai

# %%
import math
p, q, n, t = 0, 0, 0, 0
flag = 0
e, d, temp, m, en = [], [], [], [], []
msg = ""
def prime(pr):
    j = int(math.sqrt(pr))
    for i in range(2, j + 1):
        if pr % i == 0:
            return 0
    return 1
def ce():
    global e, d, t, p, q
    k = 0
    for i in range(2, t):
        if t % i == 0:
            continue
        flag = prime(i)
        if flag == 1 and i != p and i != q:
            e.append(i)
            flag = cd(e[k])
            if flag > 0:
                d.append(flag)
                k += 1
            if k == 99:
                break
def cd(x):
    k = 1
    while True:
        k = k + t
        if k % x == 0:
            return k // x
def encrypt():
    global msg, m, n, e, en, temp
    key = e[0]
    for i, char in enumerate(msg):
        pt = ord(char) - 96
        k = pow(pt, key, n)
        temp.append(k)
        ct = k + 96
        en.append(ct)
    en.append(-1)
    print("\nTHE ENCRYPTED MESSAGE IS")
    print(''.join(chr(c) for c in en[:-1]))
def decrypt():
    global temp, n, d, m
    key = d[0]
    i = 0
    while en[i] != -1:
        ct = temp[i]
        k = pow(ct, key, n)
        pt = k + 96
        m.append(pt)
        i += 1
    m.append(-1)
    print("\nTHE DECRYPTED MESSAGE IS")
    print(''.join(chr(c) for c in m[:-1]))

def main():
    global p, q, n, t, msg, m
    print("\nENTER FIRST PRIME NUMBER")
    p = int(input())
    flag = prime(p)
    if flag == 0:
        print("\nWRONG INPUT")
        return
    print("\nENTER ANOTHER PRIME NUMBER")
    q = int(input())
    flag = prime(q)
    if flag == 0 or p == q:
        print("\nWRONG INPUT")
        return
    print("\nENTER MESSAGE")
    msg = input()
    m = [ord(c) for c in msg]
    n = p * q
    t = (p - 1) * (q - 1)
    ce()
    print("\nPOSSIBLE VALUES OF e AND d ARE")
    for i in range(len(e)):
        print(f"\n{e[i]}\t{d[i]}")
    encrypt()
    decrypt()
if __name__ == "__main__":
    main()
# Out:
# ENTER FIRST PRIME NUMBER
# 3
#
# ENTER ANOTHER PRIME NUMBER
# 5
#
# ENTER MESSAGE
# sai
#
# POSSIBLE VALUES OF e AND d ARE
#
# 7	7
#
# THE ENCRYPTED MESSAGE IS
# dai
#
# THE DECRYPTED MESSAGE IS
# saidai

# %%
def power(a, b, mod):
    """Calculates (a^b) % mod using recursive exponentiation by squaring."""
    if b == 1:
        return a % mod
    t = power(a, b // 2, mod)
    if b % 2 == 0:
        return (t * t) % mod
    else:
        return ((t * t) % mod * a) % mod


def main():
    # Input values
    n = int(input("Enter the value of n (prime number): "))
    g = int(input("Enter the value of g (generator): "))
    x = int(input("Enter the value of x for the first person: "))
    a = power(g, x, n)
    y = int(input("Enter the value of y for the second person: "))
    b = power(g, y, n)

    # Calculate the shared keys
    key1 = power(b, x, n)  # Key for the first person
    key2 = power(a, y, n)  # Key for the second person
    print(f"Key for the first person is: {key1}")
    print(f"Key for the second person is: {key2}")

if __name__ == "__main__":
    main()
# Out:
# Enter the value of n (prime number): 3
# Enter the value of g (generator): 7
# Enter the value of x for the first person: 2
# Enter the value of y for the second person: 4
# Key for the first person is: 1
# Key for the second person is: 1

# %%
import hashlib
def sha1():
    try:
        md = hashlib.sha1()
        print("Message digest object info: ")
        print(f" Algorithm = {md.name}")
        print(f" Provider = {hashlib.__name__}")
        print(f" ToString = {md}")

        input_str = ""
        md.update(input_str.encode())
        output = md.digest()
        print()
        print(f"SHA1(\"{input_str}\") = {bytes_to_hex(output)}")

        input_str = "abc"
        md = hashlib.sha1()
        md.update(input_str.encode())
        output = md.digest()
        print()
        print(f"SHA1(\"{input_str}\") = {bytes_to_hex(output)}")
        input_str = "abcdefghijklmnopqrstuvwxyz"
        md = hashlib.sha1()
        md.update(input_str.encode())
        output = md.digest()
        print()
        print(f"SHA1(\"{input_str}\") = {bytes_to_hex(output)}")
        print()
    except Exception as e:
        print(f"Exception: {e}")
def bytes_to_hex(b):
    return ''.join([f'{byte:02X}' for byte in b])
if __name__ == "__main__":
    sha1()
# Out:
# Message digest object info:
#  Algorithm = sha1
#  Provider = hashlib
#  ToString = <sha1 _hashlib.HASH object @ 0x7895228234b0>
#
# SHA1("") = DA39A3EE5E6B4B0D3255BFEF95601890AFD80709
#
# SHA1("abc") = A9993E364706816ABA3E25717850C26C9CD0D89D
#
# SHA1("abcdefghijklmnopqrstuvwxyz") = 32D10C7B8CF96570CA04CE37F2A19D84240D3A89
